# %%
# Import all relevant libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Specify URL for getting S&P 500 stocks and parse them with BeautifulSoup
URL = "https://stockanalysis.com/list/sp-500-stocks/"
page = requests.get(URL)
soup = BeautifulSoup(page.text, "html.parser")

# %%
# Find the table of stocks
table = soup.find('table')

# Extract data from the table
data = []
for row in table.find_all('tr'):
    row_data = []
    for cell in row.find_all(['th', 'td']):
        row_data.append(cell.text.strip())
    data.append(row_data)

# %%
# Specify headers and data separately
headers = data[0]
data = data[1:]

# Create a dataframe with the table and index set as No.
df = pd.DataFrame(data,columns=headers)
df = df.set_index("No.")
df
# Out:
#     Symbol             Company Name Market Cap Stock Price % Change  Revenue
# No.
# 1     MSFT    Microsoft Corporation  3,115.91B      419.21    1.23%  227.58B
# 2     AAPL                Apple Inc  2,925.78B      189.22    0.61%  385.71B
# 3     GOOG            Alphabet Inc.  1,857.90B      150.15    1.99%  307.39B
# 4    GOOGL            Alphabet Inc.  1,856.82B      148.90    2.05%  307.39B
# 5     AMZN         Amazon.com, Inc.  1,803.20B      173.60    2.21%  574.79B
# ..     ...                      ...        ...         ...      ...      ...
# 499    CMA    Comerica Incorporated      6.75B       51.16    0.18%    3.72B
# 500    FMC          FMC Corporation      6.40B       51.28   -1.47%    4.49B
# 501    WHR    Whirlpool Corporation      5.98B      108.94   -1.13%   19.46B
# 502   ZION  Zions Bancorporation,NA      5.92B       39.99    0.25%    3.08B
# 503    VFC         V.F. Corporation      5.91B       15.19   -1.07%   10.82B
#
# [503 rows x 6 columns]

# %%
df.to_csv('stock tickers S&P 500.csv')
